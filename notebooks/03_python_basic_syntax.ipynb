# %%
import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import keras
#
# ModuleNotFoundError: No module named 'keras'

# %%
a = 5

# %%
b = a*4
b

# %% [markdown]
# ## Arithmetic Operations

# %%
r = 1500
t = 0.2


total = r * (1 + t)
total

# %%
2!=3

# %% [markdown]
# and or not

# %%
(10>5) and (10<5)

# %% [markdown]
# ## List

# %%
l = [10,20,30,40]

# %%
l = [10, 'test1234','mest', [40,10], 123, 8.4]

0-5

# %%
len(l)-2
# Out:
# 4

# %%
l[len(l)-2]
# Out:
# 123

# %%
len(l[1])
# Out:
# 8

# %%
len(l)

# %%
l.append(50)

# %%
l = ['data1.csv', 'data2.csv', 'data3.csv']

# %% [markdown]
# ## Tuple

# %%
t = (10, 12, 13)

# %% [markdown]
# ```sql
# INSERT INTO TABLE ... VALUES
# (value1, value2)
# ```

# %% [markdown]
# ## Set

# %%
my_list = [1, 2, 3, 4, 5,5,5,5,5]

# %%
my_set = set(my_list)
new_l = list(my_set)
new_l
# Out:
# [1, 2, 3, 4, 5]

# %%
a = {1,2,3,4,5}
b = {4,5,6,7,8}

# %%
a.intersection(b)
# Out:
# {4, 5}

# %% [markdown]
# ## Dictionary

# %%
# key value pairs
customers = {
             'Alice': 25, 
             'Bob': 30, 
             'Charlie': 35,
             'Charlie': 31,
             'Charlie': [32,2]
             }

# %%
customers
# Out:
# {'Alice': 25, 'Bob': 30, 'Charlie': [32, 2]}

# %%
customers['Alice'] = 30

# %%
customers

# %%
customer = {'name': 'Alice', 'age': 30, 'city': 'New York'}
customer['State'] = 'NY'
customer['Segment'] = 'Premium'

# %%
customer1 = customer
customer1
# Out:
# {'name': 'Alice',
#  'age': 30,
#  'city': 'New York',
#  'State': 'NY',
#  'Segment': 'Premium'}

# %%
# Bob
customer2 = {'name': 'Bob', 'age': 25, 'city': 'Los Angeles', 'State': 'CA', 'Segment': 'Standard'}

# %%
# Armen
customer3 = {'name': 'Armen', 'age': 28, 'city': 'Chicago', 'State': 'IL'}

# %%
list_of_customers = [customer1, customer2, customer3]

# %%
list_of_customers
# Out:
# [{'name': 'Alice',
#   'age': 30,
#   'city': 'New York',
#   'State': 'NY',
#   'Segment': 'Premium'},
#  {'name': 'Bob',
#   'age': 25,
#   'city': 'Los Angeles',
#   'State': 'CA',
#   'Segment': 'Standard'},
#  {'name': 'Armen', 'age': 28, 'city': 'Chicago', 'State': 'IL'}]

# %%
list(list_of_customers[0].keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 list(list_of_customers[0].keys())
#
# NameError: name 'list_of_customers' is not defined

# %%
l = [10,20,30,40]
d = {'key', 'value'}

# %% [markdown]
# ## Pandas

# %%
import pandas as pd
import numpy as np

# %%
data = {'name': ['Alice', 'Bob', 'Charlie','David','Armen'], 
        'age': [30, 25, 28, 35, 42], 
        'city': ['New York', 'Los Angeles', 'Chicago', 'Boston', 'San Francisco'],
        'revenue': [10000, 15000, 12000, 20000, 18000],
        'segment': ['Premium', 'Premium', 'Premium', 'Standard', 'Premium']}

# %%
list(data.values())

temp_list = [['v1','v2'],['c1','c2']]

# %%
temp_list[1][0]
# Out:
# ['c1', 'c2']

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#       name  age           city  revenue   segment
# 0    Alice   30       New York    10000   Premium
# 1      Bob   25    Los Angeles    15000   Premium
# 2  Charlie   28        Chicago    12000   Premium
# 3    David   35         Boston    20000  Standard
# 4    Armen   42  San Francisco    18000   Premium

# %%
df.loc[df["revenue"] > 12000,"segment"] = "High Revenue"

# %%
df.head()
# Out:
#       name  age           city  revenue       segment
# 0    Alice   30       New York    10000       Premium
# 1      Bob   25    Los Angeles    15000  High Revenue
# 2  Charlie   28        Chicago    12000       Premium
# 3    David   35         Boston    20000  High Revenue
# 4    Armen   42  San Francisco    18000  High Revenue

# %% [markdown]
# ## IF Statement

# %%
revenue = 101

if revenue > 100:
    print("High revenue")
    print(f"Because the revenue is: {revenue}")
    
else:
    print("Low Revenue")

print("Analysis complete")
# Out:
# High revenue
# Because the revenue is: 101
# Analysis complete

# %%
revenue = 100

if revenue > 200:
    print(f"Very high revenue: {revenue}")
elif revenue > 100:
    print(f"High revenue: {revenue}")
elif revenue > 50:
    print(f"Medium revenue: {revenue}")
else:
    print(f"Low revenue: {revenue}")
# Out:
# Medium revenue: 100

# %% [markdown]
# ```sql
# CASE WHEN condition THEN value_if_true ELSE value_if_false END
# ```

# %%
is_active = False


if is_active:
    print('Okay')
    # MY CODE / LOGIC

# %% [markdown]
# ## Bolean

# %%
a != b
# Out:
# True

# %%
revenue = 90
is_active = False

if revenue > 100 or is_active:
    print("Target customer")

# %%
is_active = False
if not is_active:
    print("Customer is active")
# Out:
# Customer is active

# %%
revenue = 100

if revenue == 100:
    print('Revenue is 100')
    if is_active:
        print('Great')
    else:
        print('Bad')
else:
    print('reveneu is not 100')
# Out:
# Revenue is 100
# Bad

# %% [markdown]
# ## Loops

# %%
'(? ? ? ? ? ?)'

# %%
f"({df.shape[1]*'?, '})"
# Out:
# '(?, ?, ?, ?, ?, )'

# %%
5*'a'
# Out:
# 'aaaaa'

# %%
sales = [10,20,30,40,50,84,0,212]

sales[0] = sales[0]*2
sales[1] = sales[1]*2
sales[2] = sales[2]*2
sales[3] = sales[3]*2
sales[4] = sales[4]*2

# %%
for i in range(2,10,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
sales
# Out:
# [20, 40, 60, 80, 100, 84, 0, 212]

# %%
len(sales)

for i in range(8):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for i in range(len(sales)):
    
    sales[i] = sales[i]*2

sales
# Out:
# [40, 80, 120, 160, 200, 168, 0, 424]

# %%
sales

total = 0

for i in sales:
    print(f'Total before {total}')
    print(20*'-')
    total = total + i
    print(20*'-')
    print(f'Total after {total}' )
# Out:
# Total before 0
# --------------------
# --------------------
# Total after 40
# Total before 40
# --------------------
# --------------------
# Total after 120
# Total before 120
# --------------------
# --------------------
# Total after 240
# Total before 240
# --------------------
# --------------------
# Total after 400
# Total before 400
# --------------------
# --------------------
# Total after 600
# Total before 600
# --------------------
# --------------------
# Total after 768
# Total before 768
# --------------------
# --------------------
# Total after 768
# Total before 768
# --------------------
# --------------------
# Total after 1192

# %%
sales
sales_new = []
total = 0

for i in sales:
    sales_new.append(i*2)

print(sales)
print(sales_new)
# Out:
# [40, 80, 120, 160, 200, 168, 0, 424]
# [80, 160, 240, 320, 400, 336, 0, 848]

# %%
loser = []
sales_new = []
for i in sales:
    sales_new.append(i*2)
    else:
        loser.append(i) 

print(loser)
print(sales_new)
# Out:
# [0]
# [80, 160, 240, 320, 400, 336, 848]

# %%
customer = {
    "data_name1": "data_url1",
    "data_name2": "data_url2",
    "data_name3": "data_url3",
    "data_name4": "data_url4",
    
}

for key in customer.keys():
    print(f'Download `{customer[key]}` and `save in some folder` and name it as `{key}`.csv')
# Out:
# Download `data_url1` and `save in some folder` and name it as `data_name1`.csv
# Download `data_url2` and `save in some folder` and name it as `data_name2`.csv
# Download `data_url3` and `save in some folder` and name it as `data_name3`.csv
# Download `data_url4` and `save in some folder` and name it as `data_name4`.csv

# %%
for key, value in customer.items():
    print(f'Download `{value}` and `save in some folder` and name it as `{key}`.csv')
# Out:
# Download `data_url1` and `save in some folder` and name it as `data_name1`.csv
# Download `data_url2` and `save in some folder` and name it as `data_name2`.csv
# Download `data_url3` and `save in some folder` and name it as `data_name3`.csv
# Download `data_url4` and `save in some folder` and name it as `data_name4`.csv

# %%
for i in range(3):
    for j in range(2):
        print("i =", i, ", j =", j)
# Out:
# i = 0 , j = 0
# i = 0 , j = 1
# i = 1 , j = 0
# i = 1 , j = 1
# i = 2 , j = 0
# i = 2 , j = 1

# %% [markdown]
# ## List Comprehentions

# %%
sales
# Out:
# [40, 80, 120, 160, 200, 168, 0, 424]

# %%
new_sales = [i*2 for i in sales]
new_sales
# Out:
# [80, 160, 240, 320, 400, 336, 0, 848]

# %%
a = 'abcdefg'

a_l = [i for i in a]

a_l
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
l = [10,20,20,0]

l_1 = [i for i in l if i>0]
l_0 = [i for i in l if i==0]

l_0
# Out:
# [0]

# %%
["Champion" if value>0 else "Loser" for value in l]
# Out:
# ['Champion', 'Champion', 'Champion', 'Loser']

# %%
",".join(a_l)
# Out:
# 'a,b,c,d,e,f,g'

# %%
c = a
a = b
b = c

# %%
a = a + b

# %%
b = a - b
a = a - b

# %%
print(f" a is equal to: {a}  \n b is equal to: {b}")
# Out:
#  a is equal to: 6
#  b is equal to: 5

# %%
print(revenue)
if revenue == 150:
    print("Equal")
# Out:
# 150
# Equal

# %%
a = 5; b = 10; c = 15

# %%
if revenue > 100:
    print("High")
# Out:
# High

# %%
list_of_data_sources = ['data1.csv', 'data2.csv', 'data3.csv']

# %%
for i in list_of_data_sources:
    print(f'then name of current data source is: {i}')

print("Exit loop")
# Out:
# then name of current data source is: data1.csv
# then name of current data source is: data2.csv
# then name of current data source is: data3.csv
# Exit loop

# %%
number_of_clicks = 0

for i in range(100):
    number_of_clicks = i + 1

number_of_clicks
# Out:
# 5

# %%
sales = [100, 200, 150, 50]

for value in sales:
    if value > 120:
        print("High sale:", value)
    else:
        print("Low sale:", value)
# Out:
# Low sale: 100
# High sale: 200
# High sale: 150
# Low sale: 50

# %%
customer = {
    "name": "Anna",
    "revenue": 150,
    "city": "Yerevan"
}

# %%
customer.keys()
customer['name']
# Out:
# 'Anna'

# %%
customer['city']
# Out:
# 'Yerevan'

# %%
customer['revenue']
# Out:
# 150

# %%
customer = {
    "name": ["Anna", "Gagik"],
    "revenue": [150, 200],
    "city": ["Yerevan"]
}

customer
# Out:
# {'name': ['Anna', 'Gagik'], 'revenue': [150, 200], 'city': ['Yerevan']}

# %%
customer.items()
# Out:
# dict_items([('name', ['Anna', 'Gagik']), ('revenue', [150, 200]), ('city', ['Yerevan'])])

# %%
for key, value in customer.items():
    print(key)
    print(key, ":", customer[key][1])
# Out:
# name
# name : Gagik
# revenue
# revenue : 200
# city
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 for key, value in customer.items():
#       2     print(key)
# ----> 3     print(key, ":", customer[key][1])
#
# IndexError: list index out of range

# %%
l= [10,20,30,40,50]
for i in l[3:]:
    print(i)
# Out:
# 40
# 50

# %%
l[:3]
# Out:
# [10, 20, 30]
