# %%
## Unzipping File
import zipfile
with zipfile.ZipFile("../data/raw/Archive.zip", "r") as zip_ref:
    zip_ref.extractall("../data/raw/")

# %%
del zip_ref

# %%
## Import packages
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# %%
df_orders = pd.read_csv('../data/raw/orders.csv'
    #     usecols=['order_id', 'user_id', 'order_number', 'order_dow',
    #    'order_hour_of_day', 'days_since_prior_order'
    #    ]
       )

# %%
df_orders.head(n= 5)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_orders.tail()
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
# 3421082                 14                    30.0

# %%
print(f"""
the shape of the data: {df_orders.shape}
number of rows: {df_orders.shape[0]}
number of columns: {df_orders.shape[1]}
""")
# Out:
# the shape of the data: (3421083, 7)
# number of rows: 3421083
# number of columns: 7

# %%
df_orders.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='str')

# %%
df_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_orders.rename(columns={'order_id': 'order_number','order_dow':'day_of_week'},
                 inplace= True)

# IT IS THE SAME AS df_orders = df_orders.rename(columns={'order_id': 'order_number','order_dow':'day_of_week'})

# %%
df_orders.head()
# Out:
#    order_number  user_id eval_set  order_number  day_of_week  \
# 0       2539329        1    prior             1            2
# 1       2398795        1    prior             2            3
# 2        473747        1    prior             3            3
# 3       2254736        1    prior             4            4
# 4        431534        1    prior             5            4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
type(df_orders.head())
# Out:
# pandas.DataFrame

# %%
shape = df_orders.shape
type(shape)
# Out:
# tuple

# %%
df_orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_number            int64
#  1   user_id                 int64
#  2   eval_set                str
#  3   order_number            int64
#  4   day_of_week             int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), str(1)
# memory usage: 198.9 MB

# %%
if df_orders.shape[0] > 1000000:
    print('DANGER')
else:
    print('OKAY')
# Out:
# DANGER

# %%
shape
# Out:
# (3421083, 7)

# %%
print(type(df_orders.shape))
print(f" The # of rows: {df_orders.shape[0]} \n The # of columns: {df_orders.shape[1]}")
# Out:
# <class 'tuple'>
#  The # of rows: 3421083
#  The # of columns: 7

# %%
## List of column
df_orders.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='str')

# %%
df_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_orders.tail()
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
# 3421082                 14                    30.0

# %%
df_orders.drop(columns= ['eval_set'], inplace=True)

# %%
df_orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_number            int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   day_of_week             int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
# dtypes: float64(1), int64(5)
# memory usage: 156.6 MB

# %%
df_orders.dtypes
# Out:
# order_number                int64
# user_id                     int64
# order_number                int64
# day_of_week                 int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
s

# %%
df_orders
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                   15.00
# 2                       12                   21.00
# ...

# %%
# summary statistics
df_orders.describe(exclude=['str'])
# Out:
#           order_id      user_id  order_number    order_dow  order_hour_of_day  \
# count 3,421,083.00 3,421,083.00  3,421,083.00 3,421,083.00       3,421,083.00
# mean  1,710,542.00   102,978.21         17.15         2.78              13.45
# std     987,581.74    59,533.72         17.73         2.05               4.23
# min           1.00         1.00          1.00         0.00               0.00
# 25%     855,271.50    51,394.00          5.00         1.00              10.00
# 50%   1,710,542.00   102,689.00         11.00         3.00              13.00
# 75%   2,565,812.50   154,385.00         23.00         5.00              16.00
# max   3,421,083.00   206,209.00        100.00         6.00              23.00
#
#        days_since_prior_order
# count            3,214,874.00
# mean                    11.11
# std                      9.21
# min                      0.00
# 25%                      4.00
# 50%                      7.00
# 75%                     15.00
# ...

# %%
df_orders.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='str')

# %%
df_orders.drop(columns = ['eval_set'], inplace = True)

# %%
df_orders.astype({'order_id': 'str'})

# df_orders.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df_orders.astype({'order_id': 'str'},inplace = True)
#       3 # df_orders.dtypes
#
# TypeError: NDFrame.astype() got an unexpected keyword argument 'inplace'

# %%
df_orders['order_id_str'] = df_orders['order_id'].astype('str')

df_orders.head()
df_orders.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# order_id_str                  str
# dtype: object

# %%
df_orders.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
df_orders.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order order_id_str
# 0                     NaN      2539329
# 1                   15.00      2398795
# 2                   21.00       473747
# 3                   29.00      2254736
# 4                   28.00       431534

# %%
df_orders['my_new_column'] = [int(i) for i in df_orders['order_hour_of_day']/3]
df_orders['my_new_column'] = df_orders['order_hour_of_day']//3
# df_orders['my_new_column'] = 'Testt'
df_orders.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order order_id_str  my_new_column
# 0                     NaN      2539329              2
# 1                   15.00      2398795              2
# 2                   21.00       473747              4
# 3                   29.00      2254736              2
# 4                   28.00       431534              5

# %%
df_orders_new = df_orders.assign(
    is_weekend = df_orders["order_dow"].isin([0, 6]),
    is_morning = df_orders["order_hour_of_day"] < 12,
    # is_premium = df_orders["days_since_prior_order"] <= 7
)

# %%
df_orders_new.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order order_id_str  my_new_column  is_weekend  is_morning
# 0                     NaN      2539329              2       False        True
# 1                   15.00      2398795              2       False        True
# 2                   21.00       473747              4       False       False
# 3                   29.00      2254736              2       False        True
# 4                   28.00       431534              5       False       False

# %%
df_orders['order_dow'].value_counts()
# Out:
# order_dow
# 0    600905
# 1    587478
# 2    467260
# 5    453368
# 6    448761
# 3    436972
# 4    426339
# Name: count, dtype: int64

# %%
df_orders['order_dow'].value_counts(normalize=True)
# Out:
# order_dow
# 0   0.18
# 1   0.17
# 2   0.14
# 5   0.13
# 6   0.13
# 3   0.13
# 4   0.12
# Name: proportion, dtype: float64

# %%
v_counts = pd.DataFrame(df_orders['order_dow'].value_counts(normalize=True))

v_counts.reset_index(inplace=True)

# %%
v_counts
# Out:
#    order_dow  proportion
# 0          0        0.18
# 1          1        0.17
# 2          2        0.14
# 3          5        0.13
# 4          6        0.13
# 5          3        0.13
# 6          4        0.12

# %%
v_counts.sort_values(by='order_dow',ascending=False,inplace=True)
v_counts
# Out:
#    order_dow  proportion
# 4          6        0.13
# 3          5        0.13
# 6          4        0.12
# 5          3        0.13
# 2          2        0.14
# 1          1        0.17
# 0          0        0.18

# %%
v_counts.reset_index(drop=True,inplace=True)
v_counts
# Out:
#    order_dow  proportion
# 0          6        0.13
# 1          5        0.13
# 2          4        0.12
# 3          3        0.13
# 4          2        0.14
# 5          1        0.17
# 6          0        0.18

# %%
df_orders_new['days_since_prior_order'] = df_orders_new['days_since_prior_order'].fillna(0)

# %%
df_orders_new.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order order_id_str  my_new_column  is_weekend  is_morning
# 0                    0.00      2539329              2       False        True
# 1                   15.00      2398795              2       False        True
# 2                   21.00       473747              4       False       False
# 3                   29.00      2254736              2       False        True
# 4                   28.00       431534              5       False       False

# %%
# 174MB with index and bolean column (0-N)
# 146MB առանց index
# 153MB ինդեքսով՝ առանց միհատ բուլիան սյունակի
df_orders_new.to_csv('../data/processed/order_new.csv',index=False)

# %%
df_products = pd.read_csv('../data/raw/products.csv')
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19    5.80
# 1             13    9.30
# 2              7    4.50
# 3              1   10.50
# 4             13    4.30

# %%
df_products.drop(columns=['aisle_id'],inplace=True)

# %%
df_departments = pd.read_csv('../data/raw/departments.csv')

# %%
df_departments.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_temp_t = df_departments.T
df_temp_t.head()
# Out:
#                         0
# department_id  department
# 1                  frozen
# 2                   other
# 3                  bakery
# 4                 produce

# %%
df_temp_t.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 22 entries, department_id to 21
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       22 non-null     str
# dtypes: str(1)
# memory usage: 908.0+ bytes

# %%
df_products.reset_index()
# Out:
#        index  product_id                                       product_name  \
# 0          0           1                         Chocolate Sandwich Cookies
# 1          1           2                                   All-Seasons Salt
# 2          2           3               Robust Golden Unsweetened Oolong Tea
# 3          3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4          4           5                          Green Chile Anytime Sauce
# ...      ...         ...                                                ...
# 49688  49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689  49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690  49690       49686                                   Artisan Baguette
# 49691  49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692  49692       49688                             Fresh Foaming Cleanser
#
#        department_id  prices
# ...

# %%
df_temp_t.reset_index(inplace=True)

# %%
df_temp_t.head()
# Out:
#            index           0
# 0  department_id  department
# 1              1      frozen
# 2              2       other
# 3              3      bakery
# 4              4     produce

# %%
col_names = df_temp_t.iloc[0]
col_names
# Out:
# index    department_id
# 0           department
# Name: 0, dtype: str

# %%
department_main_data = df_temp_t.iloc[1:]
department_main_data.head()
# Out:
#   index        0
# 1     1   frozen
# 2     2    other
# 3     3   bakery
# 4     4  produce
# 5     5  alcohol

# %%
department_main_data.columns = col_names

# %%
department_main_data.head()
# Out:
#   Excel      SQL
# 1     1   frozen
# 2     2    other
# 3     3   bakery
# 4     4  produce
# 5     5  alcohol

# %%
department_main_data.reset_index(inplace=True)

# %%
department_main_data.head()
# Out:
# 0  index department_id department
# 0      1             1     frozen
# 1      2             2      other
# 2      3             3     bakery
# 3      4             4    produce
# 4      5             5    alcohol

# %%
df_departments = pd.read_csv("../data/raw/departments.csv")
df_departments.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_t = df_departments.T

# %%
df_t.reset_index(inplace=True)

# %%
df_t
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
df_t.iloc[0]
# Out:
# index    department_id
# 0           department
# Name: 0, dtype: str

# %%
myl = [1,2,2,3,5]
myl[2:4]

myl[:4]
# Out:
# [1, 2, 2, 3]

# %%
df_t.columns = df_t.iloc[0]
df_t = df_t.iloc[1:]

# %%
df_t.reset_index(drop=True,inplace=True)

# %%
df_t
# Out:
# 0  department_id       department
# 0              1           frozen
# 1              2            other
# 2              3           bakery
# 3              4          produce
# 4              5          alcohol
# 5              6    international
# 6              7        beverages
# 7              8             pets
# 8              9  dry goods pasta
# 9             10             bulk
# 10            11    personal care
# 11            12     meat seafood
# 12            13           pantry
# 13            14        breakfast
# 14            15     canned goods
# 15            16       dairy eggs
# 16            17        household
# 17            18           babies
# 18            19           snacks
# 19            20             deli
# 20            21          missing

# %%
# Get current working directory
import os
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/karen/Desktop/aca/lab/python/notebooks

# %%
../data/raw/customers.csv
