# %% [markdown]
# ## Loading Packages

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Importing Dataframes

# %%
df_orders = pd.read_csv('../data/raw/orders.csv')
print(df_orders.shape)
df_orders.head()
# Out:
# (3421083, 7)
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                   15.00
# 2                   21.00
# 3                   29.00
# 4                   28.00

# %%
df_orders.head
# Out:
# <bound method NDFrame.head of          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                   15.00
# ...

# %%
df_orders['eval_set'].value_counts()
# Out:
# eval_set
# prior    3214874
# train     131209
# test       75000
# Name: count, dtype: int64

# %%
df_orders_train = df_orders[df_orders['eval_set'] == 'train']
print(df_orders_train.shape)
df_orders_train.head()

df_orders_train.to_csv('../data/processed/orders_train.csv',index=False)
# Out:
# (131209, 7)

# %%
del df_orders

# %%
df_products = pd.read_csv('../data/raw/products.csv')
print(df_products.shape)
df_products.head()
# Out:
# (49693, 5)
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_customers = pd.read_csv('../data/raw/customers.csv')
print(df_customers.shape)
df_customers.head()
# Out:
# (206209, 10)
#    user_id First Name   Surname  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_departments = pd.read_csv('../data/processed/departments_t.csv')
print(df_departments.shape)
df_departments.head()
# Out:
# (21, 2)
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
df_aisles = pd.read_csv('../data/raw/aisles.csv')
print(df_aisles.shape)
df_aisles.head()
# Out:
# (134, 2)
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
df_states = pd.read_csv('../data/raw/states.csv')
print(df_states.shape)
df_states.head()
# Out:
# (51, 3)
#            state     region     division
# 0    Connecticut  Northeast  New England
# 1          Maine  Northeast  New England
# 2  Massachusetts  Northeast  New England
# 3  New Hampshire  Northeast  New England
# 4   Rhode Island  Northeast  New England

# %%
df_order_products_train = pd.read_csv('../data/raw/order_products_train.csv')
print(df_order_products_train.shape)
df_order_products_train.head()
# Out:
# (1384617, 4)
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %% [markdown]
# ## Explore

# %% [markdown]
# ### Orders

# %%
df_orders_train.head()
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 10   1187899        1    train            11          4                  8
# 25   1492625        2    train            15          1                 11
# 49   2196797        5    train             5          0                 11
# 74    525192        7    train            21          2                 11
# 78    880375        8    train             4          1                 14
#
#     days_since_prior_order
# 10                   14.00
# 25                   30.00
# 49                    6.00
# 74                    6.00
# 78                   10.00

# %%
df_orders_train.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 131209 entries, 10 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                131209 non-null  int64
#  1   user_id                 131209 non-null  int64
#  2   eval_set                131209 non-null  str
#  3   order_number            131209 non-null  int64
#  4   order_dow               131209 non-null  int64
#  5   order_hour_of_day       131209 non-null  int64
#  6   days_since_prior_order  131209 non-null  float64
# dtypes: float64(1), int64(5), str(1)
# memory usage: 8.6 MB

# %%
columns_to_explore =['order_dow','order_hour_of_day','days_since_prior_order']

df_orders_train[columns_to_explore].describe()
# Out:
#        order_dow  order_hour_of_day  days_since_prior_order
# count 131,209.00         131,209.00              131,209.00
# mean        2.77              13.58                   17.05
# std         2.12               4.22                   10.68
# min         0.00               0.00                    0.00
# 25%         1.00              10.00                    7.00
# 50%         3.00              14.00                   15.00
# 75%         5.00              17.00                   30.00
# max         6.00              23.00                   30.00

# %%
df_orders_train.isna().sum()
# Out:
# order_id                  0
# user_id                   0
# eval_set                  0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %%
df_orders_train['order_id'].nunique()
# Out:
# 131209

# %%
df_orders_train['user_id'].nunique()
# Out:
# 131209

# %%
df_orders['order_id'].nunique()
# Out:
# 3421083

# %%
df_orders['user_id'].nunique()
# Out:
# 206209

# %%
df_orders['eval_set'].value_counts(normalize=True)
# Out:
# eval_set
# prior   0.94
# train   0.04
# test    0.02
# Name: proportion, dtype: float64

# %%
df_orders.isna().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
df_orders['order_dow'].value_counts().sort_index()
# Out:
# order_dow
# 0    600905
# 1    587478
# 2    467260
# 3    436972
# 4    426339
# 5    453368
# 6    448761
# Name: count, dtype: int64

# %%
df_orders['order_hour_of_day'].value_counts().sort_index()
# Out:
# order_hour_of_day
# 0      22758
# 1      12398
# 2       7539
# 3       5474
# 4       5527
# 5       9569
# 6      30529
# 7      91868
# 8     178201
# 9     257812
# 10    288418
# 11    284728
# 12    272841
# 13    277999
# 14    283042
# 15    283639
# 16    272553
# 17    228795
# 18    182912
# 19    140569
# 20    104292
# 21     78109
# 22     61468
# 23     40043
# Name: count, dtype: int64

# %%
df_orders['order_hour_of_day'].between(0,23).all()
# Out:
# np.True_

# %%
df_orders['order_dow'].between(0,6).all()
# Out:
# np.True_

# %%
high_sales = [value for value in sales if value > 120]

# %%
ValueError: Length of values (2232700) does not match length of index (3421083)

# %%
"High" if value > 120 else "Low"

# %%
# Out:
# ['Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Weekend',
#  'Weekend',
#  'Weekend',
#  'Weekend',
#  'Weekend',
#  'Workday',
#  'Weekend',
#  'Workday',
#  'Workday',
#  'Weekend',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Weekend',
#  'Workday',
#  'Workday',
#  'Weekend',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Weekend',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Weekend',
#  'Workday',
#  'Weekend',
#  'Weekend',
#  'Workday',
#  'Workday',
#  'Workday',
#  'Weekend',
#  'Weekend',
# ...

# %%
df_orders['weekend'] = ['Weekend' if i in  [0,6] else 'Workday' for i in df_orders['order_dow']]
df_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  weekend
# 0                     NaN  Workday
# 1                   15.00  Workday
# 2                   21.00  Workday
# 3                   29.00  Workday
# 4                   28.00  Workday

# %%
df_orders['weekend'].value_counts(normalize=True)
# Out:
# weekend
# Workday   0.69
# Weekend   0.31
# Name: proportion, dtype: float64

# %% [markdown]
# ### Customers

# %%
df_customers.head()
# Out:
#    user_id First Name   Surname  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_customers['Gender'].value_counts(normalize=True)
# Out:
# Gender
# Male     0.50
# Female   0.50
# Name: proportion, dtype: float64

# %%
df_customers[['n_dependants','fam_status']].value_counts(normalize=True)
# Out:
# n_dependants  fam_status
# 3             married                            0.23
# 1             married                            0.23
# 2             married                            0.23
# 0             single                             0.16
#               divorced/widowed                   0.09
# 2             living with parents and siblings   0.02
# 1             living with parents and siblings   0.02
# 3             living with parents and siblings   0.02
# Name: proportion, dtype: float64

# %%
df_customers[['Age','income']].describe().drop(['count'])
# Out:
#        Age     income
# mean 49.50  94,632.85
# std  18.48  42,473.79
# min  18.00  25,903.00
# 25%  33.00  59,874.00
# 50%  49.00  93,547.00
# 75%  66.00 124,244.00
# max  81.00 593,901.00

# %% [markdown]
# ### Products_Train

# %%
df_order_products_train.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
df_order_products_train.shape
# Out:
# (1384617, 4)

# %%
df_products[df_products['product_id']==24852]
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 24853       24852       Banana        24              4   12.30

# %%
df_order_products_train[['product_id','add_to_cart_order']].value_counts()
# Out:
# product_id  add_to_cart_order
# 24852       1                    4605
# 13176       1                    3889
# 24852       2                    3199
# 13176       2                    2867
# 24852       3                    2255
#                                  ...
# 7615        28                      1
# 40800       1                       1
# 33424       3                       1
# 16475       4                       1
# 6858        5                       1
# Name: count, Length: 316364, dtype: int64

# %%
basket_size = len(df_order_products_train)/df_order_products_train['order_id'].nunique()

print('Averager Market Basket: ', basket_size)
# Out:
# Averager Market Basket:  10.552759338155157

# %%
df_order_products_train['product_id'].nunique()
# Out:
# 39123

# %%
df_order_products_train['reordered'].value_counts(normalize=True)
# Out:
# reordered
# 1   0.60
# 0   0.40
# Name: proportion, dtype: float64

# %% [markdown]
# ### Products

# %%
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19    5.80
# 1             13    9.30
# 2              7    4.50
# 3              1   10.50
# 4             13    4.30

# %%
df_products['product_id'].nunique()
# Out:
# 49686

# %%
df_products['aisle_id'].nunique()
# Out:
# 134

# %%
df_products['prices'].describe()
# Out:
# count   49,693.00
# mean         9.99
# std        453.52
# min          1.00
# 25%          4.10
# 50%          7.10
# 75%         11.20
# max     99,999.00
# Name: prices, dtype: float64

# %%
df_departments
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %% [markdown]
# ## Merge
#
# `new_df = pd.merge(left_df,right_df, on = 'id', how  = 'left')`

# %%
df_products.head()
df_departments.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
df_products_departments = pd.merge(
    df_products,
    df_departments,
    on="department_id",
    how="left",
    indicator = True
)

df_products_departments.head(20)
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices department _merge
# 0             19    5.80     snacks   both
# 1             13    9.30     pantry   both
# 2              7    4.50  beverages   both
# 3              1   10.50     frozen   both
# 4             13    4.30     pantry   both

# %%
df_products_departments.dtypes
# Out:
# product_id          int64
# product_name          str
# aisle_id            int64
# department_id       int64
# prices            float64
# department            str
# _merge           category
# dtype: object

# %%
df_products_departments['_merge'].value_counts()
# Out:
# _merge
# both          49693
# left_only         0
# right_only        0
# Name: count, dtype: int64

# %%
URL = 'https://raw.githubusercontent.com/hovhannisyan91/data_analytics_with_python/refs/heads/main/data/raw/'

# %%
URL = 'https://raw.githubusercontent.com/hovhannisyan91/data_analytics_with_python/refs/heads/main/data/raw/'
l = ['customers','states']

for i in l:
    dfname = URL + i +'.csv'
    df = pd.read_csv(dfname)
    df.to_csv(f'../data/raw/{i}_1.csv')
    print(dfname)
# Out:
# https://raw.githubusercontent.com/hovhannisyan91/data_analytics_with_python/refs/heads/main/data/raw/customers.csv
# https://raw.githubusercontent.com/hovhannisyan91/data_analytics_with_python/refs/heads/main/data/raw/states.csv

# %%
import pandas as pd
SQL_URL = "https://raw.githubusercontent.com/hovhannisyan91/sql-analytics-portfolio/refs/heads/main/data/public_schema/"
TO_SAVE_URL = '/Users/karen/Desktop/aca/lab/sql_module/data/public_schema/'
l = ['customers', 'employees','orders','products', 'sales']

for i in l:
    print(100*'-')
    print(f"trying to download {i}.csv")
    print(SQL_URL+i+'.csv')
    # df = pd.read_csv(SQL_URL+i+'.csv')
    print(f"{i}.csv is downloaded")
    print(f"the shape of {i}.csv : {df.shape}")
    print(f"trying to save  {i}.csv")
    # df.to_csv(TO_SAVE_URL+i+'.csv',index=False)
    print(f"{i}.csv is successfully saved")
# Out:
# ----------------------------------------------------------------------------------------------------
# trying to download customers.csv
# https://raw.githubusercontent.com/hovhannisyan91/sql-analytics-portfolio/refs/heads/main/data/public_schema/customers.csv
# customers.csv is downloaded
# the shape of customers.csv : (5000, 8)
# trying to save  customers.csv
# customers.csv is successfully saved
# ----------------------------------------------------------------------------------------------------
# trying to download employees.csv
# https://raw.githubusercontent.com/hovhannisyan91/sql-analytics-portfolio/refs/heads/main/data/public_schema/employees.csv
# employees.csv is downloaded
# the shape of employees.csv : (5000, 8)
# trying to save  employees.csv
# employees.csv is successfully saved
# ----------------------------------------------------------------------------------------------------
# trying to download orders.csv
# ...

# %%
"/sfdsf/sdfdsfds/sdf"

# %%
d

# %%
import pandas as pd
df = pd.read_csv(URL)
df
# df.to_csv('../data/raw/customers.csv', index=False)
# Out:
#                    state     region            division
# 0            Connecticut  Northeast         New England
# 1                  Maine  Northeast         New England
# 2          Massachusetts  Northeast         New England
# 3          New Hampshire  Northeast         New England
# 4           Rhode Island  Northeast         New England
# 5                Vermont  Northeast         New England
# 6             New Jersey  Northeast     Middle Atlantic
# 7               New York  Northeast     Middle Atlantic
# 8           Pennsylvania  Northeast     Middle Atlantic
# 9               Illinois    Midwest  East North Central
# 10               Indiana    Midwest  East North Central
# 11              Michigan    Midwest  East North Central
# 12                  Ohio    Midwest  East North Central
# 13             Wisconsin    Midwest  East North Central
# 14                  Iowa    Midwest  West North Central
# 15                Kansas    Midwest  West North Central
# ...

# %% [markdown]
# ## Parquet
#
# 1. Read Parquet file
# 2. Save to CSV
# 3. Compare the sizes
#
#
# ```bash
# pip install pyarrow fastparquet
# ```

# %%
df_parquet = pd.read_parquet("../data/raw/order_products_prior.parquet")

# %%
df_parquet.shape
# Out:
# (32434489, 4)

# %%
df_parquet.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB

# %%
df_parquet.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_parquet.to_csv('../data/raw/testsize.csv',index=False)
